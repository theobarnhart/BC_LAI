# %%
from osgeo import gdal
import numpy.ma as ma

# %%
d = gdal.Open('./LC80340322014263LGN00_NDVI.tif')
ndvi = d.GetRasterBand(1).ReadAsArray()

# %%
np.nanmax(ndvi)
# Out:
# 0.72123720639575706

# %%
plt.figure(figsize=(10,10))
plt.pcolormesh(ndvi,vmin=-0.75,vmax=0.75, cmap='RdYlGn')
plt.colorbar()

# %%
ndvi.max()
# Out:
# nan

# %%
b4[b4==-0.9999]=np.NaN
b5[b5==-0.9999]=np.NaN

# %%
ndvi = (b5-b4)/(b5+b4)

# %%
ndvi = ma.masked_values(ndvi,np.NaN)

# %%
plt.figure(figsize=(10,10))
plt.pcolormesh(ndvi)
plt.colorbar()

# %%
# Out:
# array([[-9999, -9999, -9999, ..., -9999, -9999, -9999],
#        [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#        [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#        ...,
#        [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#        [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#        [-9999, -9999, -9999, ..., -9999, -9999, -9999]], dtype=int16)

# %%
d.Get
# Out:
# {'AREA_OR_POINT': 'Area', 'Band_1': 'band 5 surface reflectance'}
